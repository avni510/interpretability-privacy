# %%
import models_runner as models_runner
import utils as utils
import plot_utils as plot_utils
import os

# %%
ROOT_DIR = os.path.dirname(os.getcwd())
EXPERIMENT_DIR = ROOT_DIR + "/experiments/adult"

# %%
plot_utils.plot_train_baseline_models(EXPERIMENT_DIR, iter_val=0)

# %%
plot_utils.display_test_baseline_results(EXPERIMENT_DIR, iter_val=0)
# Out:
# Test Loss/ Accuracies
# Losses [0.37971107733135406, 0.39817561836431203, 0.40369917583256104, 0.3511094152689361]
# Accuracies [0.8268, 0.814, 0.8196, 0.8448]

# %%
plot_utils.plot_train_attack_models(EXPERIMENT_DIR, iter_val=0)
# Out:
# Attack Training Accuracies and Losses
# Plot of class 0
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/6k/wgyn7p4d0_188x778mjmjtph0000gp/T/ipykernel_50610/3215767739.py in <module>
# ----> 1 plot_utils.plot_train_attack_models(EXPERIMENT_DIR, iter_val=0)
#
# ~/Desktop/UCSD/Research/interpretability-privacy/src/plot_utils.py in plot_train_attack_models(experiment_dir, iter_val, num_models)
#      70
#      71         print(model_infos[0]['attack_train_losses'])
# ---> 72         train_losses = [info['attack_train_losses'][class_val] for info in model_infos]
#      73         train_accuracies = [info['attack_train_accuracies'][class_val] for info in model_infos]
#      74
#
# ~/Desktop/UCSD/Research/interpretability-privacy/src/plot_utils.py in <listcomp>(.0)
#      70
#      71         print(model_infos[0]['attack_train_losses'])
# ---> 72         train_losses = [info['attack_train_losses'][class_val] for info in model_infos]
#      73         train_accuracies = [info['attack_train_accuracies'][class_val] for info in model_infos]
#      74
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plot_utils.display_attack_test_results(EXPERIMENT_DIR, iter_val=0)
