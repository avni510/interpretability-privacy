# %%
import models_runner as models_runner
import utils as utils
import plot_utils as plot_utils
import os

# %%
ROOT_DIR = os.path.dirname(os.getcwd())
EXPERIMENT_DIR = ROOT_DIR + "/experiments/adult"

# %%
plot_utils.plot_train_baseline_models(EXPERIMENT_DIR, iter_val=0)

# %%
plot_utils.display_test_baseline_results(EXPERIMENT_DIR, iter_val=0)
# Out:
# Test Loss/ Accuracies
# Losses [0.42328414775597784, 0.39598337289529106, 0.37787788739790934, 0.4096157859308651]
# Accuracies [0.802, 0.82, 0.8284, 0.8136]

# %%
plot_utils.plot_train_attack_models(EXPERIMENT_DIR, iter_val=0)
# Out:
# Attack Training Accuracies and Losses
# Plot of class 0
# Plot of class 1

# %%
plot_utils.display_attack_test_results(EXPERIMENT_DIR, iter_val=0)
# Out:
# Attack Test Accuracies and Losses
# Losses and Accuracies of class 0
# Losses
# [0.6930590479766728, 0.693715376387663, 0.6957042533759923, 0.6935342661896895]
# ------------------------------
# Accuracies
# [0.5053995680345572, 0.5024221453287198, 0.4935726412806209, 0.49248473461719117]
#
# Losses and Accuracies of class 1
# Losses
# [0.6986672124772701, 0.6928803977512178, 0.6980928323485635, 0.6966905606553909]
# ------------------------------
# Accuracies
# [0.48619447779111646, 0.4992481203007519, 0.4982896237172178, 0.5026954177897575]
